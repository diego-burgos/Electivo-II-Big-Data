# %% [markdown]
# <a href="https://colab.research.google.com/github/diego-burgos/Electivo-II-Big-Data/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSN9tGbaAKzPq5PSHuRfkZ3TPJ_GPlRsBCa0fwlhW77gkxUWWNFgJBOKSdQMmo5cQ/pub?gid=901716613&single=true&output=csv", index_col="Fecha")

# %%
datos
# Out:
#            Peru  Bolivia  Brasil  Argentina  Chile  Mexico  Alemania
# Fecha
# 20/3/2020     1        1       0          0      0       3         0
# 21/3/2020    15        5       5          9      2      32         1
# 22/3/2020    26       10       7         11      3      54         3
# 23/3/2020    37       15      20         23      4      62         4
# 24/3/2020    54       32      31         31      9      81         6
# 25/3/2020    73       43      33         35     12     108         8
# 26/3/2020    75       51      48         43     15     117        10
# 27/3/2020    91       69      63         51     19     144        11
# 28/3/2020   109       78      70         53     20     174        13
# 29/3/2020   117       93      85         54     24     191        14
# 30/3/2020   127      111      88         63     29     203        16
# 31/3/2020   131      123      90         64     32     204        17
# ...

# %%
pip install bar-chart-race

# %%
import pandas as pd
import bar_chart_race as bcr
bcr.bar_chart_race(df=datos,filename="video_grafico.mp4", title="Número de casos por países")
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
